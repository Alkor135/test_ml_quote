# %% [markdown]
# # График движения цены после свечи в выбранным кодом по Лиховидову

# %%
import pandas as pd

# %%
# Загружаем файл с разделителем ',' в DF, индексом делаем поле 'date_time'
df = pd.read_csv('c:\data_prepare_quote_csv\SPFB.RTS_5min_2020-09-01_2020-11-10_lihovidov.csv', delimiter=',')
df = df.set_index(pd.to_datetime(df['date_time'], format='%Y-%m-%d %H:%M:%S'))  # Меняем индекс и делаем его типом datetime
df = df.drop('date_time', 1)  # Удаляем колонку с датой и временем, т.к. дата-время у нас теперь в индексе
df
# Out:
#                          date    time      open      high       low     close  \
# date_time
# 2020-09-01 10:00:00  20200901  100000  126200.0  127210.0  126200.0  127030.0
# 2020-09-01 10:05:00  20200901  100500  127030.0  127320.0  127000.0  127120.0
# 2020-09-01 10:10:00  20200901  101000  127130.0  127180.0  126820.0  127160.0
# 2020-09-01 10:15:00  20200901  101500  127170.0  127380.0  127090.0  127180.0
# 2020-09-01 10:20:00  20200901  102000  127190.0  127640.0  127190.0  127490.0
# ...                       ...     ...       ...       ...       ...       ...
# 2020-11-10 23:25:00  20201110  232500  123270.0  123330.0  123190.0  123290.0
# 2020-11-10 23:30:00  20201110  233000  123300.0  123300.0  123190.0  123210.0
# 2020-11-10 23:35:00  20201110  233500  123200.0  123200.0  123100.0  123110.0
# 2020-11-10 23:40:00  20201110  234000  123120.0  123210.0  123110.0  123190.0
# 2020-11-10 23:45:00  20201110  234500  123190.0  123290.0  123130.0  123200.0
#
#                        vol  candle_code
# date_time
# 2020-09-01 10:00:00  24238        107.0
# 2020-09-01 10:05:00  16623         94.0
# 2020-09-01 10:10:00   9791         84.0
# 2020-09-01 10:15:00  13324         93.0
# 2020-09-01 10:20:00  11582        127.0
# ...                    ...          ...
# 2020-11-10 23:25:00    844         92.0
# 2020-11-10 23:30:00    728          1.0
# 2020-11-10 23:35:00   1418          2.0
# 2020-11-10 23:40:00    879        106.0
# 2020-11-10 23:45:00   2370         93.0
#
# [8020 rows x 8 columns]

# %%
# Создаем DF с заданным кодом
df_candle_code = df.query('candle_code == 0')
print(df_candle_code.shape)
# df_candle_code
# Out:
# (35, 8)

# %%
# Перебираем строки DF df_candle_code
for index, row in df_candle_code.iterrows():  # Перебираем строки dataframe df_candle_code
    df_posl = df[index:].head(20)  # Создаем последующий DF
    
    price_at_t0 = df_posl.iloc[0, 5]  # Берем самое первое по времени значение (к нему нормализуем)
    df_posl[index] = df_posl.apply(lambda row: row['close'] / price_at_t0, axis=1)  # axis=1 Указывает на колонку
    
    print(df_posl)
    break
# Out:
#                          date    time      open      high       low     close  \
# date_time
# 2020-09-04 14:10:00  20200904  141000  122930.0  122930.0  122580.0  122730.0
